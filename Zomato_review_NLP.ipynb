# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\sjeev\\Documents\\Python\\Jupyter_nbook\\NLP\\Zomato Review Dataset\\Zomato Review Kaggle.csv")

# %%
df.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
df.isnull().sum()
# Out:
# Review    0
# Liked     0
# dtype: int64

# %%
df["Liked"].value_counts()
# Out:
# Liked
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
df["Review"][999]
# Out:
# "Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check."

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
corpus=[]
from nltk.stem.porter import PorterStemmer
for i in range(999):
    Reviews=re.sub("[a-zA-Z]"," ",df["Review"][i])
    Reviews=Reviews.lower()
    Reviews=Reviews.split()
    stop_wrd=stopwords.words("english")
    stop_wrd.remove("not")
    ps=PorterStemmer()
    words=[ps.stem(i) for i in Reviews if not i in set(stop_wrd)]
    Reviews=" ".join(Reviews)
    corpus.append(Reviews)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sjeev\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df["Review"][999]
# Out:
# "Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check."

# %%
corpus
# Out:
# ['... .',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  "' .)",
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  ', , ... !',
#  '.',
#  '.',
#  '.',
#  '.',
#  ', .',
#  '.',
#  '!',
#  ', .',
#  '.',
#  '... .',
#  '.',
#  "' .... ..... .",
#  '- .',
#  ', .',
#  '4 , .',
#  '.',
#  ', , 23 .',
#  '!',
#  '.',
#  ', .',
#  ', .',
#  '.',
#  '.',
#  ', .',
#  '!',
#  '.',
#  '.',
#  '.',
#  "' .",
#  ', .',
#  ', .',
#  '.',
#  "' .",
#  ', .',
#  '!!!!!',
#  ', .',
#  '.',
#  '.',
#  '!',
#  ", ' .",
#  '!',
#  '... , , .',
#  '- .',
#  '5 .',
#  ', .',
#  ', .',
#  '10 .',
#  '!!!',
#  '.',
#  "' .",
#  '.',
#  ', .',
#  '!',
#  '.....',
#  '.',
#  '.',
#  '5 2 , .',
#  '- , , .',
#  '.',
#  '30 , .',
#  ", , ' .",
#  '.',
#  '2 - !',
#  '.',
#  "' .",
#  '.',
#  "' .",
#  '2 .',
#  '.',
#  '!',
#  '.',
#  '.',
#  '.',
#  '!!!',
#  '!',
#  '!',
#  ', .',
#  "' , ' .",
#  ', !',
#  '!!!',
#  '!',
#  "' .",
#  '!',
#  '!',
#  '.',
#  ', .',
#  ', !',
#  ", ' .",
#  ', .',
# ...
